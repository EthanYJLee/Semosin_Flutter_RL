# %%
from bs4 import BeautifulSoup
import urllib.request as req
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd

# %%
# Chrome Browser와 Chrome Driver Version 확인하기
chrom_options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrom_options)
driver.get('https://www.29cm.co.kr/shop/category/list?category_large_code=274100100')

# %%
xpath = '/html/body/shop-root/div/section/ui-list-category/div/div/div[3]/ul/li[1]'
driver.find_element(By.XPATH,xpath).click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
reviews = soup.select('.css-1gk1nxz')

# %%
for review in reviews:
    print(review.string.strip())
# Out:
# 막차인가 싶지만 이쁘면 장땡아닌가요?
# 깔끔하고 예뻐요!! 우연히 재고 확인하고 바로 주문해버렸어여!! 사이즈 230-235 발볼보통인데 여유있게 업해서 주문하라는 후기들 보고 235주문했습니다. 역시나 여유있네요 230도 맞을뻔? 그래도 전체적으로 감싸줘서 여유있게 크게 신어도 괜찮을듯요
# 평소 운동화는 230 신는데 발볼 좁다고 사이즈업하라는 후기가 많아서 고민 많이 했어요
# 근데 칼발이어서 그냥 정사이즈 230 구매했는데 음
# 235샀으면 길이가 좀 남았을거같긴하네요
# 제가 발등이 높은편도 아닌데 이건 좀 타이트하더라고요 길이나 발볼은 괜찮아서 교환할까 고민했는데 많이 불편하지는 않아서 그냥 신기로 했어요 애매하네요 살로몬 사이즈는 ㅠ 괜찮으면 다른 신발도 살까 했는데 그냥 이걸로 만족하려고요
# 코디하기에는 아주 좋은 신발입니다
# 막차라고 하는데.. 그러든지 말던지 사이즈 맨날 없어서 사고 싶어도 못 샀는데 사니까 속이 다 시원하네요ㅋㅋ
# 신발은 보통 다 250신는 252cm입니다 발등 높지 않고 볼이 얇은 편이고 발에 살이 없어요
# 발 길이에 맞춰 255cm 구매 했습니다.
# 250샀으면 좀 답답했을 것 같구요 약간 앞코가 넉넉한게 좋네요 저는!
# 매번 픔절이였던! 제 사이즈가 드디어 입고 되고 고민 1도 없이 주문 했습니다!! 약간 뒷북 느낌이 없지 않아 있지지만^^ 여러 컬러 고민 중에 머니머니 해도 기본인게 좋겠다 싶어서 블랙으루 샀어요! 한사이즈 크게 주문해야 잘 맞다 해서(발볼이 넓은편) 업해서 구매 했어요! 배송도 다음날 바로 왔어요!!
# 살로몬 팬텀 너무 사고싶었는데 항상 사이즈 품절이라 구매못했는데 이번에 재입고 알림받고 브랜드 쿠폰까지 써서 저렴하게 잘 구입했어요~^^
# 사기전 후기 정독하며 사이즈 고민이 많았는데 사이즈 작게 나왔다는 분들은 발볼이 좁아서 그러신 것 같아요 제가 볼 좁은 칼발인데 발 길이에 맞추니 딱 좋더라구요~ 발볼이 넓으면 사이즈 업하시고 보통이나 좁으신분들은 정사이즈 추천합니다^^
# ...

# %%
# 별점
soup.select('path')
# Out:
# [<path d="M0 0h24v24H0z"></path>,
#  <path d="m16.545 13.727-4.554-4.545-4.536 4.526" stroke="#000000" stroke-width="2"></path>,
#  <path d="M0 0h24v24H0z"></path>,
#  <path d="m16.545 13.727-4.554-4.545-4.536 4.526" stroke="#000000" stroke-width="2"></path>,
#  <path d="M0 0h24v24H0z"></path>,
#  <path d="m16.545 13.727-4.554-4.545-4.536 4.526" stroke="#000000" stroke-width="2"></path>,
#  <path d="M1 0l40 40.083L1.166 80" fill="none" fill-rule="evenodd" stroke="#000000" stroke-width="5"></path>,
#  <path d="M1 0l40 40.083L1.166 80" fill="none" fill-rule="evenodd" stroke="#000000" stroke-width="5"></path>,
#  <path d="M1 0l40 40.083L1.166 80" fill="none" fill-rule="evenodd" stroke="#5d5d5d" stroke-width="10"></path>,
#  <path d="M9 6.088C9 3.831 10.791 2 13 2s4 1.83 4 4.088c0 1.743-1.46 3.23-1.46 3.23L9 16 2.46 9.318S1 7.83 1 6.088C1 3.831 2.791 2 5 2s4 1.83 4 4.088z" fill="#ffffff" fill-rule="evenodd" stroke="#5d5d5d" stroke-width="0.7"></path>,
# ...
